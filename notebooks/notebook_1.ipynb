# %%
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords

# nltk.download("all")  for installing all stuff, ranging upto 3-4GBnltk.download('punkt') 
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Umar
# [nltk_data]     Dawood\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to C:\Users\Umar
# [nltk_data]     Dawood\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\Umar
# [nltk_data]     Dawood\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
sentence = """Hello World"""
tokens = nltk.word_tokenize(sentence)
tokens
# Out:
# ['Hello', 'World']

# %%
token = nltk.sent_tokenize(sentence)
token
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 token = nltk.sent_tokenize(sentence)
#       2 token
#
# NameError: name 'nltk' is not defined

# %%
text = "Hello word. NLP is amazing!"

# %%
text.split()
# Out:
# ['Hello', 'word.', 'NLP', 'is', 'amazing!']

# %%
stop_words = set(stopwords.words('english'))
text = "The quick brown fox jumps over a lazy dog"
tokens = word_tokenize(text.lower())
filtered = [t for t in tokens if t not in stop_words and t.isalpha()]

filtered
# Out:
# ['quick', 'brown', 'fox', 'jumps', 'lazy', 'dog']
